# %% [markdown]
# Weinberger, S. (2013). Speech accent archive. George Mason University.
# Dataset provided by GMU.

# %% [markdown]
# Sagar Ranga - rsagar@vt.edu <br>
# Shaheer Sajid - shaheer@vt.edu

# %% [markdown]
# Team 6 - Accent Multiclassification

# %%
import pandas as pd       
import os 
import math 
import numpy as np
import matplotlib.pyplot as plt  
import IPython.display as ipd  # To play sound in the notebook

# %% [markdown]
# Download the dataset from Kaggle and extract it to the data folder.
# https://www.kaggle.com/datasets/rtatman/speech-accent-archive/data

# %%
os.chdir("C:/Users/sagar/Documents/ML/Final Project/ML-AccentMulticlassification/data")
print(os.listdir("C:/Users/sagar/Documents/ML/Final Project/ML-AccentMulticlassification/data"))
# Out:
# ['mlruns', 'multiple_accent_classification', 'reading-passage.txt', 'recordings', 'speakers_all.csv']

# %%
#load the data 
df = pd.read_csv("speakers_all.csv", header=0)

# Check the data
print(df.shape, 'is the shape of the dataset') 
print('------------------------') 
print(df.head())
# Out:
# (2172, 12) is the shape of the dataset
# ------------------------
#     age  age_onset              birthplace  filename native_language   sex  \
# 0  24.0       12.0         koussi, senegal   balanta         balanta  male
# 1  18.0       10.0          buea, cameroon  cameroon        cameroon  male
# 2  48.0        8.0  hong, adamawa, nigeria  fulfulde        fulfulde  male
# 3  42.0       42.0   port-au-prince, haiti   haitian         haitian  male
# 4  40.0       35.0   port-au-prince, haiti   haitian         haitian  male
#
#    speakerid   country  file_missing?  Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0        788   senegal           True         NaN          NaN         NaN
# 1       1953  cameroon           True         NaN          NaN         NaN
# 2       1037   nigeria           True         NaN          NaN         NaN
# 3       1165     haiti           True         NaN          NaN         NaN
# 4       1166     haiti           True         NaN          NaN         NaN

# %% [markdown]
# Columns 9-11 are empty so we clean up the dataframe.

# %%
df.drop(df.columns[9:12],axis = 1, inplace = True)
print(df.columns)
df.describe()
# Out:
# Index(['age', 'age_onset', 'birthplace', 'filename', 'native_language', 'sex',
#        'speakerid', 'country', 'file_missing?'],
#       dtype='object')
#                age    age_onset    speakerid
# count  2172.000000  2172.000000  2172.000000
# mean     33.117173     8.833333  1088.449355
# std      14.453039     8.451127   628.420329
# min       0.000000     0.000000     1.000000
# 25%      22.000000     0.000000   543.750000
# 50%      28.000000     8.000000  1088.500000
# 75%      41.000000    13.000000  1632.250000
# max      97.000000    86.000000  2176.000000

# %%
df.groupby("native_language")['age'].describe().sort_values(by=['count'],ascending=False)
# Out:
#                  count       mean        std   min    25%   50%   75%   max
# native_language
# english          579.0  34.482729  16.734510   6.0  21.00  29.0  44.0  90.0
# spanish          162.0  34.129630  13.972528  17.0  23.00  30.0  45.0  80.0
# arabic           102.0  30.950980  12.047248  18.0  21.25  28.0  38.0  70.0
# mandarin          65.0  30.015385   8.193924  18.0  24.00  28.0  34.0  53.0
# french            63.0  33.333333  16.246091  18.0  21.00  27.0  39.0  78.0
# ...                ...        ...        ...   ...    ...   ...   ...   ...
# ife                1.0  30.000000        NaN  30.0  30.00  30.0  30.0  30.0
# ilonggo            1.0  53.000000        NaN  53.0  53.00  53.0  53.0  53.0
# irish              1.0  28.000000        NaN  28.0  28.00  28.0  28.0  28.0
# jola               1.0  34.000000        NaN  34.0  34.00  34.0  34.0  34.0
# zulu               1.0  24.000000        NaN  24.0  24.00  24.0  24.0  24.0
#
# [214 rows x 8 columns]

# %% [markdown]
# There are 214 different native language speakers. However, the top 5 native languages don't distinguish speakers well enough.

# %%
df.groupby("country")['age'].describe().sort_values(by=['count'],ascending=False)
# Out:
#                    count       mean        std   min    25%   50%   75%   max
# country
# usa                393.0  35.652672  18.044364   6.0  21.00  29.0  47.0  90.0
# china               88.0  29.477273   9.654940  18.0  23.00  27.0  33.0  72.0
# uk                  67.0  33.104478  14.900818  18.0  20.00  30.0  38.0  71.0
# india               59.0  30.864407  11.501810  18.0  22.00  28.0  35.0  64.0
# canada              54.0  31.629630  14.713998  18.0  21.25  26.5  37.5  78.0
# ...                  ...        ...        ...   ...    ...   ...   ...   ...
# chad                 1.0  21.000000        NaN  21.0  21.00  21.0  21.0  21.0
# burundi              1.0  36.000000        NaN  36.0  36.00  36.0  36.0  36.0
# the bahamas          1.0  19.000000        NaN  19.0  19.00  19.0  19.0  19.0
# malawi               1.0  42.000000        NaN  42.0  42.00  42.0  42.0  42.0
# equatorial guinea    1.0  20.000000        NaN  20.0  20.00  20.0  20.0  20.0
#
# [176 rows x 8 columns]

# %% [markdown]
# Ordering by countries brings us back to 176 rows. Top 5 countries of speakers is much different from the native languages. Additionally, USA can be further subdivided for accents from different regions in there.

# %%
df.groupby("sex")['age'].describe()
# Out:
#          count       mean        std   min   25%   50%   75%   max
# sex
# famale     1.0  65.000000        NaN  65.0  65.0  65.0  65.0  65.0
# female  1048.0  34.072519  15.337869   0.0  22.0  29.0  43.0  89.0
# male    1123.0  32.197240  13.492936   0.0  22.0  28.0  39.0  97.0

# %% [markdown]
# About an equal count of male to female speakers.

# %%
df.groupby("birthplace")['age'].describe().sort_values(by=['count'],ascending=False)
# Out:
#                               count       mean        std   min   25%   50%  \
# birthplace
# seoul, south korea             25.0  32.040000  12.300000  18.0  23.0  27.0
# skopje, macedonia              21.0  20.047619   1.160870  19.0  19.0  20.0
# hong kong, china               19.0  23.473684   4.753577  18.0  19.5  22.0
# addis ababa, ethiopia          16.0  28.875000   8.663140  20.0  22.5  27.5
# bogota, colombia               14.0  36.785714  20.881271  17.0  21.0  30.5
# ...                             ...        ...        ...   ...   ...   ...
# jalandhar, india                1.0  42.000000        NaN  42.0  42.0  42.0
# jalisco, mexico                 1.0  45.000000        NaN  45.0  45.0  45.0
# jammu, kashmir, india           1.0  25.000000        NaN  25.0  25.0  25.0
# jamshedpur, jharkhand, india    1.0  29.000000        NaN  29.0  29.0  29.0
# lewisville, texas, usa          1.0  21.000000        NaN  21.0  21.0  21.0
#
#                                 75%   max
# birthplace
# seoul, south korea            40.00  62.0
# skopje, macedonia             20.00  24.0
# hong kong, china              27.00  33.0
# addis ababa, ethiopia         31.00  52.0
# bogota, colombia              48.25  80.0
# ...                             ...   ...
# jalandhar, india              42.00  42.0
# jalisco, mexico               45.00  45.0
# jammu, kashmir, india         25.00  25.0
# jamshedpur, jharkhand, india  29.00  29.0
# lewisville, texas, usa        21.00  21.0
#
# [1290 rows x 8 columns]

# %%
df.groupby("filename")['age'].describe().sort_values(by=['count'],ascending=False).head(10)
# Out:
#             count       mean        std   min    25%   50%    75%   max
# filename
# haitian       6.0  36.333333  13.952300  18.0  25.75  41.0  42.75  54.0
# swiss         5.0  30.200000   8.318654  21.0  24.00  30.0  34.00  42.0
# nicaragua     4.0  37.000000  12.569805  20.0  32.75  39.0  43.25  50.0
# jamaican      3.0  36.333333  28.307832  19.0  20.00  21.0  45.00  69.0
# liberian      2.0  33.000000   7.071068  28.0  30.50  33.0  35.50  38.0
# hawai'i       2.0  71.000000   2.828427  69.0  70.00  71.0  72.00  73.0
# afrikaans1    1.0  27.000000        NaN  27.0  27.00  27.0  27.00  27.0
# mandarin46    1.0  43.000000        NaN  43.0  43.00  43.0  43.00  43.0
# mandarin42    1.0  47.000000        NaN  47.0  47.00  47.0  47.00  47.0
# mandarin43    1.0  24.000000        NaN  24.0  24.00  24.0  24.00  24.0

# %%
fname = 'recordings/recordings/' + 'english27.mp3'
ipd.Audio(fname)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Seeing the data provided, the best way to classify the accents would be a country based classifier.

# %% [markdown]
# Plan to use librosa library to perform MFCC feature extraction on the audio files.

# %%
import librosa
import librosa.display

# %%
# MFCC for female 
SAMPLE_RATE = 22050
fname_f = 'recordings/recordings/' + 'english385.mp3'  
y, sr = librosa.load(fname_f, sr=SAMPLE_RATE, duration = 5) # Chop audio at 5 secs... 
mfcc = librosa.feature.mfcc(y=y, sr=SAMPLE_RATE, n_mfcc = 20) # 5 MFCC components

plt.figure(figsize=(12, 6))
plt.subplot(3,1,1)
librosa.display.specshow(mfcc)
plt.ylabel('MFCC')
plt.colorbar()

# %%
# MFCC for male  
SAMPLE_RATE = 22050
fname_m = 'recordings/recordings/' + 'english381.mp3'  
y, sr = librosa.load(fname_m, sr=SAMPLE_RATE, duration = 5)
mfcc = librosa.feature.mfcc(y=y, sr=SAMPLE_RATE, n_mfcc = 20)

plt.figure(figsize=(12, 6))
plt.subplot(3,1,1)
librosa.display.specshow(mfcc)
plt.ylabel('MFCC')
plt.colorbar()

# %%
import torch
import torchaudio
import torchaudio.transforms as transforms

# %%
fname_m = 'recordings/recordings/english385.mp3'
waveform, sample_rate = torchaudio.load(fname_m, normalize=True)

# Resample if needed (if your sample rate is not 22050)
resampler = transforms.Resample(orig_freq=sample_rate, new_freq=22050)
waveform = resampler(waveform)

# Compute MFCCs
mfcc_transform = transforms.MFCC(
    sample_rate=22050,
    n_mfcc=10,  # Number of MFCC features
    melkwargs={'n_fft': 400, 'hop_length': 160, 'n_mels': 40}
)
mfcc = mfcc_transform(waveform)

# Display MFCCs
plt.figure(figsize=(12, 6))
plt.subplot(3, 1, 1)
plt.imshow(mfcc[0].detach().numpy(), cmap='viridis', origin='lower', aspect='auto')
plt.ylabel('MFCC')
plt.colorbar()
plt.show()

# %%
mfcc
# Out:
# tensor([[[-216.3252, -206.4052, -207.9324,  ..., -203.0300, -200.8715,
#           -206.5858],
#          [  33.0318,   38.7279,   36.9994,  ...,   51.6909,   48.0851,
#             41.6934],
#          [   6.1854,    5.2527,    4.9118,  ...,   -2.5246,   -9.2375,
#            -10.8919],
#          ...,
#          [   1.6038,    2.0768,    7.5726,  ...,   -2.3788,   -4.1762,
#            -12.6310],
#          [   0.7999,    0.6544,    0.5445,  ...,    2.6766,    4.9561,
#             -0.4202],
#          [  -5.7705,   -4.5411,   -1.9718,  ...,    1.8993,    1.3310,
#              0.2366]]])

# %%
fname_m = 'recordings/recordings/english381.mp3'
waveform, sample_rate = torchaudio.load(fname_m, normalize=True)

# Resample if needed (if your sample rate is not 22050)
resampler = transforms.Resample(orig_freq=sample_rate, new_freq=22050)
waveform = resampler(waveform)

# Compute MFCCs
mfcc_transform = transforms.MFCC(
    sample_rate=22050,
    n_mfcc=10,  # Number of MFCC features
    melkwargs={'n_fft': 400, 'hop_length': 160, 'n_mels': 40}
)
mfcc = mfcc_transform(waveform)

# Display MFCCs
plt.figure(figsize=(12, 6))
plt.subplot(3, 1, 1)
plt.imshow(mfcc[0].detach().numpy(), cmap='viridis', origin='lower', aspect='auto')
plt.ylabel('MFCC')
plt.colorbar()
plt.show()

# %% [markdown]
# Torch Audio MFCC extraction works well and our model will be trained in torch.

# %%
import transformers
import gc
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# %% [markdown]
# We get the labels from the audio files using the csv file. One hot encoding is used to convert labels to numbers.

# %%
RATE_HZ = 16000 # resampling rate in Hz
MAX_LENGTH = 160000 # maximum audio interval length to consider (= RATE_HZ * SECONDS)
labels = ['usa', 'china', 'uk', 'india', 'canada', 'other']
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = i
    id2label[i] = label

print(id2label, '\n\n', label2id)
# Out:
# {0: 'usa', 1: 'china', 2: 'uk', 3: 'india', 4: 'canada', 5: 'other'}
#
#  {'usa': 0, 'china': 1, 'uk': 2, 'india': 3, 'canada': 4, 'other': 5}

# %%
print(type(label2id['usa']))
# Out:
# <class 'int'>

# %% [markdown]
# CNN takes torch.long as inputs, not int. Testing here to convert the labels to torch.long

# %%
label2id_torch = {k: torch.tensor(v, dtype=torch.long) for k, v in label2id.items()}

label2id_torch
# Out:
# {'usa': tensor(0),
#  'china': tensor(1),
#  'uk': tensor(2),
#  'india': tensor(3),
#  'canada': tensor(4),
#  'other': tensor(5)}

# %%
from pathlib import Path

# %%
lang_counter = dict()

def load_data(df):
    file_list = []
    label_list = []
    for index, row in df.iterrows():
        country = row['country']  #'country' is the column containing country labels
        filename = row['filename']
        file_missing = row['file_missing?']
        
        # Skip if the file is missing
        if file_missing:
            continue
            
        lang = country  # 'country' represents the language label
        
        if lang not in lang_counter.keys():
            lang_counter[lang] = 1
        else:
            lang_counter[lang] += 1

        # if not in our selected langs then 'other'
        if lang not in labels[:-1]:
            lang = labels[-1]
        
        file_list.append(f'recordings/recordings/{filename}.mp3')
        label_list.append(label2id[lang])
    dd = pd.DataFrame()
    dd['file'] = file_list
    dd['label'] = label_list
    return dd

# %%
# %%time
dd = load_data(df)
dd.sample(5)
# Out:
# CPU times: total: 0 ns
# Wall time: 49.6 ms
#                                       file  label
# 879    recordings/recordings/english71.mp3      0
# 113     recordings/recordings/arabic75.mp3      5
# 505   recordings/recordings/english256.mp3      0
# 2024   recordings/recordings/turkish21.mp3      5
# 812   recordings/recordings/english532.mp3      0

# %%
dd['label'].value_counts()
# Out:
# label
# 5    1482
# 0     391
# 1      88
# 2      67
# 3      58
# 4      54
# Name: count, dtype: int64

# %% [markdown]
# Random Undersampling and Oversampling done to normalize the dataset.

# %%
# random undersampling of a majority class
rus = RandomUnderSampler(random_state=83, sampling_strategy='majority')
y = dd[['label']]
dd = dd.drop(['label'], axis=1)
dd, y_resampled = rus.fit_resample(dd, y)
del y
dd['label'] = y_resampled
del y_resampled
# random oversampling of all minority classes
y = dd[['label']]
dd = dd.drop(['label'], axis=1)
ros = RandomOverSampler(random_state=83)
dd, y_resampled = ros.fit_resample(dd, y)
del y
dd['label'] = y_resampled
del y_resampled
gc.collect()
# Out:
# 4780

# %%
dd.shape, dd['label'].value_counts()
# Out:
# ((2346, 2),
#  label
#  0    391
#  1    391
#  2    391
#  3    391
#  4    391
#  5    391
#  Name: count, dtype: int64)

# %%
from tqdm import tqdm
tqdm.pandas()

# %% [markdown]
# Preprocessing the audio files to resample and transform it. We take only the first 10 seconds of the audio.

# %%
def get_transform_audio(file):
    audio,rate = torchaudio.load(str(file))
    transform = torchaudio.transforms.Resample(rate,RATE_HZ)
    audio = transform(audio).squeeze(0).numpy()
    audio = audio[:MAX_LENGTH] # truncate to first part of audio to save RAM
    return audio

dd['audio'] = dd['file'].progress_apply(get_transform_audio)
# Out:
# 100%|██████████| 2346/2346 [00:46<00:00, 50.25it/s]

# %%
# %%time
dd = dd.drop(['file'], axis=1)
# Out:
# CPU times: total: 0 ns
# Wall time: 8.51 ms

# %%
dd.sample(5)
# Out:
#       label                                              audio
# 1702      4  [0.02397908, 0.038726434, 0.039565787, 0.04125...
# 1022      2  [7.812888e-06, 1.0128381e-05, 8.668688e-06, 1....
# 129       0  [-0.025472583, -0.028658083, -0.0133714825, -0...
# 575       3  [0.005326325, 0.009433268, 0.008846956, 0.0095...
# 1969      4  [0.001017792, 0.0018787439, 0.0025226392, 0.00...

# %%
from datasets import Dataset, ClassLabel, DatasetDict

dd = Dataset.from_pandas(dd)

# %%
newdd = torch.tensor(dd['label'], dtype=torch.long)

# %%
from collections import Counter
Counter(dd['label']).items()
# Out:
# dict_items([(0, 391), (1, 391), (2, 391), (3, 391), (4, 391), (5, 391)])

# %% [markdown]
# Splitting the data into 80-20 split

# %%
dd = dd.train_test_split(test_size=0.2)
dd
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'audio'],
#         num_rows: 1876
#     })
#     test: Dataset({
#         features: ['label', 'audio'],
#         num_rows: 470
#     })
# })

# %%
from transformers import AutoFeatureExtractor, AutoModelForAudioClassification

model_str = "facebook/wav2vec2-base-960h" 
feature_extractor=AutoFeatureExtractor.from_pretrained(model_str)
model=AutoModelForAudioClassification.from_pretrained(model_str,num_labels=len(labels))
model.config.id2label = id2label
# number of trainable parameters
print(model.num_parameters(only_trainable=True)/1e6)
# Out:
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 94.570118

# %%
dd["test"]
# Out:
# Dataset({
#     features: ['label', 'audio'],
#     num_rows: 470
# })

# %% [markdown]
# Preprocessing function that converts the dictionary labels from int to torch.long

# %%
def preprocess_function(batch):    
    inputs = {}
    inputs['labels'] = torch.tensor(batch['label'], dtype=torch.long)

    return inputs

dd['test'] = dd['test'].map(preprocess_function, remove_columns="label", batched=False)
dd['train'] = dd['train'].map(preprocess_function, remove_columns="label", batched=False)
# Out:
# Map:   0%|          | 0/470 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1876 [00:00<?, ? examples/s]

# %%
dd["test"]
# Out:
# Dataset({
#     features: ['audio', 'labels'],
#     num_rows: 470
# })

# %% [markdown]
# Performing Feature Extraction on the transformed audio

# %%
def preprocess_function(batch):    

    inputs = feature_extractor(batch['audio'], sampling_rate=RATE_HZ, max_length=MAX_LENGTH, truncation=True)
    inputs['input_values'] = inputs['input_values'][0]

    return inputs

dd['test'] = dd['test'].map(preprocess_function, remove_columns="audio", batched=False)
dd['train'] = dd['train'].map(preprocess_function, remove_columns="audio", batched=False)
# Out:
# Map:   0%|          | 0/470 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1876 [00:00<?, ? examples/s]

# %%
# Assign the modified inputs back to the dataset
dd['test'].set_format(type='torch', columns=['labels', 'input_values'])
dd['train'].set_format(type='torch', columns=['labels', 'input_values'])

# %%
# Verify if the modified dataset contains the converted labels
print("Test dataset:")
print(dd['test']['labels'][:5])  # Print the first 5 converted labels in the test dataset
print("Train dataset:")
print(dd['train']['labels'][:5])  # Print the first 5 converted labels in the train dataset
# Out:
# Test dataset:
# tensor([2, 3, 3, 3, 1])
# Train dataset:
# tensor([0, 3, 4, 1, 2])

# %%
gc.collect()
# Out:
# 193

# %%
dd['test']
# Out:
# Dataset({
#     features: ['labels', 'input_values'],
#     num_rows: 470
# })

# %%
dd['test']['labels']
# Out:
# tensor([2, 3, 3, 3, 1, 5, 0, 3, 0, 0, 5, 5, 5, 4, 4, 4, 1, 3, 2, 1, 4, 4, 3, 3,
#         0, 3, 1, 2, 5, 1, 5, 1, 3, 0, 3, 3, 0, 2, 5, 2, 5, 4, 2, 4, 5, 1, 5, 0,
#         5, 4, 4, 4, 1, 0, 5, 3, 4, 0, 5, 4, 4, 4, 3, 3, 3, 1, 3, 1, 1, 4, 4, 1,
#         3, 5, 2, 2, 0, 2, 2, 3, 0, 3, 5, 4, 5, 1, 2, 2, 2, 2, 2, 0, 0, 5, 2, 4,
#         2, 2, 1, 5, 0, 2, 5, 0, 0, 1, 1, 2, 4, 1, 0, 0, 5, 0, 5, 1, 3, 0, 5, 5,
#         5, 1, 3, 1, 4, 4, 0, 1, 1, 5, 0, 5, 4, 3, 3, 0, 4, 2, 5, 3, 4, 4, 2, 0,
#         4, 0, 0, 5, 2, 5, 5, 4, 4, 5, 3, 0, 3, 2, 1, 1, 4, 5, 2, 4, 5, 3, 5, 4,
#         4, 1, 3, 3, 0, 1, 0, 1, 5, 4, 2, 3, 2, 2, 5, 1, 5, 2, 0, 4, 2, 1, 3, 3,
#         4, 3, 2, 4, 2, 4, 3, 0, 5, 4, 2, 1, 5, 3, 4, 4, 2, 3, 1, 1, 4, 3, 3, 4,
#         2, 2, 2, 2, 2, 1, 3, 1, 1, 4, 1, 4, 1, 1, 3, 2, 1, 3, 5, 4, 0, 2, 5, 5,
#         5, 5, 3, 3, 5, 2, 3, 5, 2, 4, 1, 4, 1, 0, 0, 0, 0, 1, 2, 2, 2, 3, 0, 3,
#         5, 1, 5, 0, 2, 4, 3, 3, 1, 1, 1, 1, 2, 5, 5, 0, 5, 3, 4, 2, 4, 3, 0, 2,
#         4, 1, 1, 1, 3, 3, 0, 1, 5, 4, 3, 5, 1, 0, 3, 0, 0, 2, 3, 3, 3, 0, 5, 1,
#         1, 5, 2, 0, 5, 3, 4, 3, 5, 1, 0, 0, 0, 2, 4, 3, 1, 0, 1, 3, 5, 0, 4, 5,
#         4, 5, 2, 0, 0, 5, 5, 1, 2, 1, 2, 3, 0, 5, 1, 5, 2, 2, 1, 3, 2, 3, 4, 4,
#         4, 2, 3, 5, 4, 1, 2, 4, 4, 1, 2, 1, 4, 3, 1, 1, 1, 5, 1, 2, 1, 2, 1, 3,
#         3, 3, 1, 2, 4, 5, 2, 0, 3, 1, 1, 1, 5, 0, 1, 1, 1, 3, 2, 3, 1, 4, 0, 2,
#         1, 1, 1, 2, 5, 5, 5, 3, 5, 1, 0, 2, 4, 2, 4, 0, 4, 0, 5, 0, 3, 4, 2, 5,
#         1, 2, 0, 3, 2, 1, 3, 4, 2, 3, 2, 4, 5, 1, 5, 0, 1, 3, 1, 1, 0, 4, 2, 4,
#         3, 5, 3, 2, 5, 4, 0, 0, 5, 2, 4, 1, 5, 1])

# %% [markdown]
# Evaluation function for the model

# %%
import evaluate

accuracy = evaluate.load("accuracy")

from sklearn.metrics import roc_auc_score
def compute_metrics(eval_pred):
    # Compute the ROC AUC score
    predictions = eval_pred.predictions
    predictions = np.exp(predictions)/np.exp(predictions).sum(axis=1, keepdims=True)
    label_ids = eval_pred.label_ids
    roc_auc = roc_auc_score(label_ids, predictions, average='macro', multi_class='ovr')
    
    # Calculate accuracy using the loaded accuracy metric
    acc_score = accuracy.compute(predictions=predictions.argmax(axis=1), references=label_ids)['accuracy']
    
    return {
        "roc_auc": roc_auc,
        "accuracy": acc_score
    }

# %%
dd
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'input_values'],
#         num_rows: 1876
#     })
#     test: Dataset({
#         features: ['labels', 'input_values'],
#         num_rows: 470
#     })
# })

# %%
dd["test"]
# Out:
# Dataset({
#     features: ['labels', 'input_values'],
#     num_rows: 470
# })

# %% [markdown]
# This is our trainer parameters for training the model

# %%
from transformers import TrainingArguments, Trainer
from torch.optim.lr_scheduler import ReduceLROnPlateau

batch_size=4
warmup_steps=50
weight_decay=0.02
num_train_epochs=1
model_name = "multiple_accent_classification"
training_args = TrainingArguments(
    output_dir=model_name,
    logging_dir='./logs',
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    learning_rate=1e-5, # 3e-5
    logging_strategy='steps',
    logging_first_step=True,
    load_best_model_at_end=True,
    logging_steps=1,
    evaluation_strategy='epoch',
    warmup_steps=warmup_steps,
    weight_decay=weight_decay,
    eval_steps=1,
    gradient_accumulation_steps=1, 
    gradient_checkpointing=True,
    save_strategy='epoch',
    save_total_limit=1, # save fewer checkpoints to limit used space
    report_to="mlflow",  # log to mlflow
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dd["train"],
    eval_dataset=dd["test"],
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
)
# Out:
# c:\Users\sagar\anaconda3\Lib\site-packages\accelerate\accelerator.py:436: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False)
#   warnings.warn(

# %% [markdown]
# We evaluate the trainer before training, train it, then evaluate again to see how it improved

# %%
trainer.evaluate()
# Out:
#   0%|          | 0/118 [00:00<?, ?it/s]
# {'eval_loss': 1.7899272441864014,
#  'eval_roc_auc': 0.5230731292747257,
#  'eval_accuracy': 0.19148936170212766,
#  'eval_runtime': 342.1764,
#  'eval_samples_per_second': 1.374,
#  'eval_steps_per_second': 0.345}

# %%
trainer.train()
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# c:\Users\sagar\anaconda3\Lib\site-packages\torch\utils\checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.7839, 'learning_rate': 2.0000000000000002e-07, 'epoch': 0.0}
# {'loss': 1.7921, 'learning_rate': 4.0000000000000003e-07, 'epoch': 0.0}
# {'loss': 1.7879, 'learning_rate': 6.000000000000001e-07, 'epoch': 0.01}
# {'loss': 1.7835, 'learning_rate': 8.000000000000001e-07, 'epoch': 0.01}
# {'loss': 1.7965, 'learning_rate': 1.0000000000000002e-06, 'epoch': 0.01}
# {'loss': 1.7799, 'learning_rate': 1.2000000000000002e-06, 'epoch': 0.01}
# {'loss': 1.779, 'learning_rate': 1.4000000000000001e-06, 'epoch': 0.01}
# {'loss': 1.7916, 'learning_rate': 1.6000000000000001e-06, 'epoch': 0.02}
# {'loss': 1.7971, 'learning_rate': 1.8000000000000001e-06, 'epoch': 0.02}
# {'loss': 1.768, 'learning_rate': 2.0000000000000003e-06, 'epoch': 0.02}
# {'loss': 1.8028, 'learning_rate': 2.2e-06, 'epoch': 0.02}
# {'loss': 1.8035, 'learning_rate': 2.4000000000000003e-06, 'epoch': 0.03}
# {'loss': 1.7926, 'learning_rate': 2.6e-06, 'epoch': 0.03}
# {'loss': 1.8033, 'learning_rate': 2.8000000000000003e-06, 'epoch': 0.03}
# {'loss': 1.7325, 'learning_rate': 3e-06, 'epoch': 0.03}
# {'loss': 1.8014, 'learning_rate': 3.2000000000000003e-06, 'epoch': 0.03}
# {'loss': 1.7718, 'learning_rate': 3.4000000000000005e-06, 'epoch': 0.04}
# {'loss': 1.7871, 'learning_rate': 3.6000000000000003e-06, 'epoch': 0.04}
# {'loss': 1.7933, 'learning_rate': 3.8000000000000005e-06, 'epoch': 0.04}
# {'loss': 1.775, 'learning_rate': 4.000000000000001e-06, 'epoch': 0.04}
# {'loss': 1.7781, 'learning_rate': 4.2000000000000004e-06, 'epoch': 0.04}
# {'loss': 1.7833, 'learning_rate': 4.4e-06, 'epoch': 0.05}
# {'loss': 1.7776, 'learning_rate': 4.600000000000001e-06, 'epoch': 0.05}
# {'loss': 1.6499, 'learning_rate': 4.800000000000001e-06, 'epoch': 0.05}
# {'loss': 1.8028, 'learning_rate': 5e-06, 'epoch': 0.05}
# {'loss': 1.7772, 'learning_rate': 5.2e-06, 'epoch': 0.06}
# {'loss': 1.7855, 'learning_rate': 5.400000000000001e-06, 'epoch': 0.06}
# {'loss': 1.7957, 'learning_rate': 5.600000000000001e-06, 'epoch': 0.06}
# {'loss': 1.7965, 'learning_rate': 5.8e-06, 'epoch': 0.06}
# {'loss': 1.8902, 'learning_rate': 6e-06, 'epoch': 0.06}
# {'loss': 1.8016, 'learning_rate': 6.200000000000001e-06, 'epoch': 0.07}
# {'loss': 1.789, 'learning_rate': 6.4000000000000006e-06, 'epoch': 0.07}
# {'loss': 1.8037, 'learning_rate': 6.600000000000001e-06, 'epoch': 0.07}
# {'loss': 1.7572, 'learning_rate': 6.800000000000001e-06, 'epoch': 0.07}
# {'loss': 1.8659, 'learning_rate': 7e-06, 'epoch': 0.07}
# {'loss': 1.8001, 'learning_rate': 7.2000000000000005e-06, 'epoch': 0.08}
# {'loss': 2.0011, 'learning_rate': 7.4e-06, 'epoch': 0.08}
# {'loss': 1.7951, 'learning_rate': 7.600000000000001e-06, 'epoch': 0.08}
# {'loss': 1.7427, 'learning_rate': 7.800000000000002e-06, 'epoch': 0.08}
# {'loss': 1.8108, 'learning_rate': 8.000000000000001e-06, 'epoch': 0.09}
# {'loss': 1.7974, 'learning_rate': 8.2e-06, 'epoch': 0.09}
# {'loss': 1.7759, 'learning_rate': 8.400000000000001e-06, 'epoch': 0.09}
# {'loss': 1.8145, 'learning_rate': 8.6e-06, 'epoch': 0.09}
# {'loss': 1.8113, 'learning_rate': 8.8e-06, 'epoch': 0.09}
# {'loss': 1.7825, 'learning_rate': 9e-06, 'epoch': 0.1}
# {'loss': 1.6921, 'learning_rate': 9.200000000000002e-06, 'epoch': 0.1}
# {'loss': 1.8121, 'learning_rate': 9.4e-06, 'epoch': 0.1}
# {'loss': 1.8205, 'learning_rate': 9.600000000000001e-06, 'epoch': 0.1}
# {'loss': 1.7986, 'learning_rate': 9.800000000000001e-06, 'epoch': 0.1}
# {'loss': 1.4508, 'learning_rate': 1e-05, 'epoch': 0.11}
# {'loss': 1.8124, 'learning_rate': 9.976133651551314e-06, 'epoch': 0.11}
# {'loss': 1.79, 'learning_rate': 9.952267303102627e-06, 'epoch': 0.11}
# {'loss': 1.7823, 'learning_rate': 9.928400954653938e-06, 'epoch': 0.11}
# {'loss': 1.7898, 'learning_rate': 9.904534606205252e-06, 'epoch': 0.12}
# {'loss': 1.8007, 'learning_rate': 9.880668257756564e-06, 'epoch': 0.12}
# {'loss': 1.8063, 'learning_rate': 9.856801909307876e-06, 'epoch': 0.12}
# {'loss': 1.8184, 'learning_rate': 9.83293556085919e-06, 'epoch': 0.12}
# {'loss': 1.8159, 'learning_rate': 9.809069212410502e-06, 'epoch': 0.12}
# {'loss': 1.7981, 'learning_rate': 9.785202863961815e-06, 'epoch': 0.13}
# {'loss': 1.8044, 'learning_rate': 9.761336515513126e-06, 'epoch': 0.13}
# {'loss': 1.792, 'learning_rate': 9.73747016706444e-06, 'epoch': 0.13}
# {'loss': 1.7899, 'learning_rate': 9.713603818615752e-06, 'epoch': 0.13}
# {'loss': 1.8007, 'learning_rate': 9.689737470167065e-06, 'epoch': 0.13}
# {'loss': 1.7776, 'learning_rate': 9.665871121718378e-06, 'epoch': 0.14}
# {'loss': 1.811, 'learning_rate': 9.64200477326969e-06, 'epoch': 0.14}
# {'loss': 1.7873, 'learning_rate': 9.618138424821004e-06, 'epoch': 0.14}
# {'loss': 1.7859, 'learning_rate': 9.594272076372316e-06, 'epoch': 0.14}
# {'loss': 1.78, 'learning_rate': 9.570405727923628e-06, 'epoch': 0.14}
# {'loss': 1.7854, 'learning_rate': 9.54653937947494e-06, 'epoch': 0.15}
# {'loss': 1.7931, 'learning_rate': 9.522673031026253e-06, 'epoch': 0.15}
# {'loss': 1.7768, 'learning_rate': 9.498806682577566e-06, 'epoch': 0.15}
# {'loss': 1.786, 'learning_rate': 9.474940334128879e-06, 'epoch': 0.15}
# {'loss': 1.8015, 'learning_rate': 9.451073985680192e-06, 'epoch': 0.16}
# {'loss': 1.7966, 'learning_rate': 9.427207637231505e-06, 'epoch': 0.16}
# {'loss': 1.7881, 'learning_rate': 9.403341288782816e-06, 'epoch': 0.16}
# {'loss': 1.7705, 'learning_rate': 9.37947494033413e-06, 'epoch': 0.16}
# {'loss': 1.789, 'learning_rate': 9.355608591885442e-06, 'epoch': 0.16}
# {'loss': 1.7902, 'learning_rate': 9.331742243436755e-06, 'epoch': 0.17}
# {'loss': 1.7932, 'learning_rate': 9.307875894988068e-06, 'epoch': 0.17}
# {'loss': 1.9124, 'learning_rate': 9.28400954653938e-06, 'epoch': 0.17}
# {'loss': 1.7824, 'learning_rate': 9.260143198090693e-06, 'epoch': 0.17}
# {'loss': 1.7773, 'learning_rate': 9.236276849642005e-06, 'epoch': 0.17}
# {'loss': 1.8085, 'learning_rate': 9.212410501193319e-06, 'epoch': 0.18}
# {'loss': 1.796, 'learning_rate': 9.18854415274463e-06, 'epoch': 0.18}
# {'loss': 1.7984, 'learning_rate': 9.164677804295943e-06, 'epoch': 0.18}
# {'loss': 1.7837, 'learning_rate': 9.140811455847256e-06, 'epoch': 0.18}
# {'loss': 1.7794, 'learning_rate': 9.116945107398569e-06, 'epoch': 0.19}
# {'loss': 1.7911, 'learning_rate': 9.093078758949882e-06, 'epoch': 0.19}
# {'loss': 1.7964, 'learning_rate': 9.069212410501193e-06, 'epoch': 0.19}
# {'loss': 1.8288, 'learning_rate': 9.045346062052508e-06, 'epoch': 0.19}
# {'loss': 1.7749, 'learning_rate': 9.021479713603819e-06, 'epoch': 0.19}
# {'loss': 1.8047, 'learning_rate': 8.997613365155132e-06, 'epoch': 0.2}
# {'loss': 1.7899, 'learning_rate': 8.973747016706445e-06, 'epoch': 0.2}
# {'loss': 1.7833, 'learning_rate': 8.949880668257757e-06, 'epoch': 0.2}
# {'loss': 1.7955, 'learning_rate': 8.92601431980907e-06, 'epoch': 0.2}
# {'loss': 1.7898, 'learning_rate': 8.902147971360383e-06, 'epoch': 0.2}
# {'loss': 2.0085, 'learning_rate': 8.878281622911696e-06, 'epoch': 0.21}
# {'loss': 1.798, 'learning_rate': 8.854415274463007e-06, 'epoch': 0.21}
# {'loss': 1.789, 'learning_rate': 8.83054892601432e-06, 'epoch': 0.21}
# {'loss': 1.8035, 'learning_rate': 8.806682577565633e-06, 'epoch': 0.21}
# {'loss': 1.8971, 'learning_rate': 8.782816229116946e-06, 'epoch': 0.22}
# {'loss': 1.7788, 'learning_rate': 8.758949880668259e-06, 'epoch': 0.22}
# {'loss': 1.772, 'learning_rate': 8.735083532219572e-06, 'epoch': 0.22}
# {'loss': 1.7848, 'learning_rate': 8.711217183770883e-06, 'epoch': 0.22}
# {'loss': 1.8092, 'learning_rate': 8.687350835322197e-06, 'epoch': 0.22}
# {'loss': 1.795, 'learning_rate': 8.663484486873509e-06, 'epoch': 0.23}
# {'loss': 1.7956, 'learning_rate': 8.639618138424822e-06, 'epoch': 0.23}
# {'loss': 1.7907, 'learning_rate': 8.615751789976134e-06, 'epoch': 0.23}
# {'loss': 1.7966, 'learning_rate': 8.591885441527447e-06, 'epoch': 0.23}
# {'loss': 1.7788, 'learning_rate': 8.56801909307876e-06, 'epoch': 0.23}
# {'loss': 2.0087, 'learning_rate': 8.544152744630071e-06, 'epoch': 0.24}
# {'loss': 1.9001, 'learning_rate': 8.520286396181386e-06, 'epoch': 0.24}
# {'loss': 1.7743, 'learning_rate': 8.496420047732697e-06, 'epoch': 0.24}
# {'loss': 1.7918, 'learning_rate': 8.47255369928401e-06, 'epoch': 0.24}
# {'loss': 1.793, 'learning_rate': 8.448687350835323e-06, 'epoch': 0.25}
# {'loss': 1.8104, 'learning_rate': 8.424821002386636e-06, 'epoch': 0.25}
# {'loss': 1.7981, 'learning_rate': 8.400954653937949e-06, 'epoch': 0.25}
# {'loss': 1.7986, 'learning_rate': 8.37708830548926e-06, 'epoch': 0.25}
# {'loss': 1.7681, 'learning_rate': 8.353221957040574e-06, 'epoch': 0.25}
# {'loss': 1.7829, 'learning_rate': 8.329355608591886e-06, 'epoch': 0.26}
# {'loss': 1.8092, 'learning_rate': 8.305489260143198e-06, 'epoch': 0.26}
# {'loss': 1.808, 'learning_rate': 8.281622911694511e-06, 'epoch': 0.26}
# {'loss': 1.7926, 'learning_rate': 8.257756563245824e-06, 'epoch': 0.26}
# {'loss': 1.7981, 'learning_rate': 8.233890214797137e-06, 'epoch': 0.26}
# {'loss': 1.7981, 'learning_rate': 8.210023866348448e-06, 'epoch': 0.27}
# {'loss': 1.7973, 'learning_rate': 8.186157517899763e-06, 'epoch': 0.27}
# {'loss': 1.787, 'learning_rate': 8.162291169451074e-06, 'epoch': 0.27}
# {'loss': 1.8021, 'learning_rate': 8.138424821002387e-06, 'epoch': 0.27}
# {'loss': 1.8136, 'learning_rate': 8.1145584725537e-06, 'epoch': 0.28}
# {'loss': 1.7814, 'learning_rate': 8.090692124105013e-06, 'epoch': 0.28}
# {'loss': 1.8004, 'learning_rate': 8.066825775656326e-06, 'epoch': 0.28}
# {'loss': 1.7705, 'learning_rate': 8.042959427207638e-06, 'epoch': 0.28}
# {'loss': 1.8174, 'learning_rate': 8.01909307875895e-06, 'epoch': 0.28}
# {'loss': 1.7839, 'learning_rate': 7.995226730310263e-06, 'epoch': 0.29}
# {'loss': 1.7903, 'learning_rate': 7.971360381861575e-06, 'epoch': 0.29}
# {'loss': 1.801, 'learning_rate': 7.947494033412888e-06, 'epoch': 0.29}
# {'loss': 1.8015, 'learning_rate': 7.923627684964201e-06, 'epoch': 0.29}
# {'loss': 1.7767, 'learning_rate': 7.899761336515514e-06, 'epoch': 0.29}
# {'loss': 1.7877, 'learning_rate': 7.875894988066827e-06, 'epoch': 0.3}
# {'loss': 1.772, 'learning_rate': 7.852028639618138e-06, 'epoch': 0.3}
# {'loss': 1.8065, 'learning_rate': 7.828162291169453e-06, 'epoch': 0.3}
# {'loss': 1.792, 'learning_rate': 7.804295942720764e-06, 'epoch': 0.3}
# {'loss': 1.797, 'learning_rate': 7.780429594272077e-06, 'epoch': 0.3}
# {'loss': 1.8155, 'learning_rate': 7.75656324582339e-06, 'epoch': 0.31}
# {'loss': 1.8121, 'learning_rate': 7.732696897374703e-06, 'epoch': 0.31}
# {'loss': 1.7879, 'learning_rate': 7.708830548926015e-06, 'epoch': 0.31}
# {'loss': 1.7962, 'learning_rate': 7.684964200477327e-06, 'epoch': 0.31}
# {'loss': 1.7901, 'learning_rate': 7.661097852028641e-06, 'epoch': 0.32}
# {'loss': 1.8056, 'learning_rate': 7.637231503579952e-06, 'epoch': 0.32}
# {'loss': 1.7878, 'learning_rate': 7.613365155131266e-06, 'epoch': 0.32}
# {'loss': 1.7842, 'learning_rate': 7.589498806682578e-06, 'epoch': 0.32}
# {'loss': 1.7926, 'learning_rate': 7.565632458233891e-06, 'epoch': 0.32}
# {'loss': 1.765, 'learning_rate': 7.541766109785204e-06, 'epoch': 0.33}
# {'loss': 1.7764, 'learning_rate': 7.517899761336516e-06, 'epoch': 0.33}
# {'loss': 1.7961, 'learning_rate': 7.494033412887829e-06, 'epoch': 0.33}
# {'loss': 1.7884, 'learning_rate': 7.470167064439141e-06, 'epoch': 0.33}
# {'loss': 1.8087, 'learning_rate': 7.446300715990455e-06, 'epoch': 0.33}
# {'loss': 1.7944, 'learning_rate': 7.422434367541767e-06, 'epoch': 0.34}
# {'loss': 1.7983, 'learning_rate': 7.3985680190930795e-06, 'epoch': 0.34}
# {'loss': 1.7948, 'learning_rate': 7.3747016706443915e-06, 'epoch': 0.34}
# {'loss': 1.9669, 'learning_rate': 7.350835322195705e-06, 'epoch': 0.34}
# {'loss': 1.7594, 'learning_rate': 7.326968973747017e-06, 'epoch': 0.35}
# {'loss': 1.7852, 'learning_rate': 7.303102625298329e-06, 'epoch': 0.35}
# {'loss': 1.7938, 'learning_rate': 7.279236276849643e-06, 'epoch': 0.35}
# {'loss': 1.788, 'learning_rate': 7.255369928400955e-06, 'epoch': 0.35}
# {'loss': 1.8115, 'learning_rate': 7.231503579952268e-06, 'epoch': 0.35}
# {'loss': 1.7849, 'learning_rate': 7.20763723150358e-06, 'epoch': 0.36}
# {'loss': 1.8138, 'learning_rate': 7.183770883054894e-06, 'epoch': 0.36}
# {'loss': 1.8997, 'learning_rate': 7.159904534606206e-06, 'epoch': 0.36}
# {'loss': 1.7714, 'learning_rate': 7.136038186157519e-06, 'epoch': 0.36}
# {'loss': 1.7644, 'learning_rate': 7.112171837708831e-06, 'epoch': 0.36}
# {'loss': 1.7995, 'learning_rate': 7.088305489260144e-06, 'epoch': 0.37}
# {'loss': 1.7644, 'learning_rate': 7.0644391408114565e-06, 'epoch': 0.37}
# {'loss': 1.7838, 'learning_rate': 7.0405727923627685e-06, 'epoch': 0.37}
# {'loss': 1.8022, 'learning_rate': 7.016706443914082e-06, 'epoch': 0.37}
# {'loss': 1.7815, 'learning_rate': 6.992840095465394e-06, 'epoch': 0.38}
# {'loss': 1.7741, 'learning_rate': 6.968973747016707e-06, 'epoch': 0.38}
# {'loss': 1.7863, 'learning_rate': 6.945107398568019e-06, 'epoch': 0.38}
# {'loss': 1.7832, 'learning_rate': 6.921241050119333e-06, 'epoch': 0.38}
# {'loss': 1.8025, 'learning_rate': 6.897374701670645e-06, 'epoch': 0.38}
# {'loss': 1.8187, 'learning_rate': 6.873508353221957e-06, 'epoch': 0.39}
# {'loss': 1.7906, 'learning_rate': 6.849642004773271e-06, 'epoch': 0.39}
# {'loss': 1.7982, 'learning_rate': 6.825775656324583e-06, 'epoch': 0.39}
# {'loss': 1.8002, 'learning_rate': 6.801909307875896e-06, 'epoch': 0.39}
# {'loss': 1.7892, 'learning_rate': 6.778042959427208e-06, 'epoch': 0.39}
# {'loss': 1.7447, 'learning_rate': 6.754176610978521e-06, 'epoch': 0.4}
# {'loss': 1.7959, 'learning_rate': 6.7303102625298334e-06, 'epoch': 0.4}
# {'loss': 1.8049, 'learning_rate': 6.706443914081146e-06, 'epoch': 0.4}
# {'loss': 1.793, 'learning_rate': 6.682577565632458e-06, 'epoch': 0.4}
# {'loss': 1.7867, 'learning_rate': 6.658711217183771e-06, 'epoch': 0.41}
# {'loss': 1.7739, 'learning_rate': 6.634844868735084e-06, 'epoch': 0.41}
# {'loss': 1.784, 'learning_rate': 6.610978520286396e-06, 'epoch': 0.41}
# {'loss': 1.7738, 'learning_rate': 6.58711217183771e-06, 'epoch': 0.41}
# {'loss': 1.772, 'learning_rate': 6.563245823389022e-06, 'epoch': 0.41}
# {'loss': 1.7859, 'learning_rate': 6.539379474940335e-06, 'epoch': 0.42}
# {'loss': 1.7844, 'learning_rate': 6.515513126491647e-06, 'epoch': 0.42}
# {'loss': 1.7948, 'learning_rate': 6.4916467780429605e-06, 'epoch': 0.42}
# {'loss': 1.7836, 'learning_rate': 6.467780429594273e-06, 'epoch': 0.42}
# {'loss': 1.817, 'learning_rate': 6.443914081145585e-06, 'epoch': 0.42}
# {'loss': 1.7831, 'learning_rate': 6.420047732696898e-06, 'epoch': 0.43}
# {'loss': 1.7912, 'learning_rate': 6.39618138424821e-06, 'epoch': 0.43}
# {'loss': 1.7712, 'learning_rate': 6.372315035799523e-06, 'epoch': 0.43}
# {'loss': 2.0036, 'learning_rate': 6.348448687350835e-06, 'epoch': 0.43}
# {'loss': 1.7805, 'learning_rate': 6.324582338902149e-06, 'epoch': 0.43}
# {'loss': 1.8, 'learning_rate': 6.300715990453461e-06, 'epoch': 0.44}
# {'loss': 1.7701, 'learning_rate': 6.276849642004774e-06, 'epoch': 0.44}
# {'loss': 1.8026, 'learning_rate': 6.252983293556086e-06, 'epoch': 0.44}
# {'loss': 1.7991, 'learning_rate': 6.2291169451074e-06, 'epoch': 0.44}
# {'loss': 1.7869, 'learning_rate': 6.205250596658712e-06, 'epoch': 0.45}
# {'loss': 1.7982, 'learning_rate': 6.181384248210024e-06, 'epoch': 0.45}
# {'loss': 1.7863, 'learning_rate': 6.1575178997613375e-06, 'epoch': 0.45}
# {'loss': 1.7905, 'learning_rate': 6.1336515513126495e-06, 'epoch': 0.45}
# {'loss': 1.7732, 'learning_rate': 6.109785202863962e-06, 'epoch': 0.45}
# {'loss': 1.7249, 'learning_rate': 6.0859188544152745e-06, 'epoch': 0.46}
# {'loss': 1.802, 'learning_rate': 6.062052505966588e-06, 'epoch': 0.46}
# {'loss': 1.7966, 'learning_rate': 6.0381861575179e-06, 'epoch': 0.46}
# {'loss': 1.8069, 'learning_rate': 6.014319809069213e-06, 'epoch': 0.46}
# {'loss': 1.7985, 'learning_rate': 5.990453460620526e-06, 'epoch': 0.46}
# {'loss': 1.7918, 'learning_rate': 5.966587112171838e-06, 'epoch': 0.47}
# {'loss': 1.8054, 'learning_rate': 5.942720763723151e-06, 'epoch': 0.47}
# {'loss': 1.7774, 'learning_rate': 5.918854415274463e-06, 'epoch': 0.47}
# {'loss': 1.7835, 'learning_rate': 5.894988066825777e-06, 'epoch': 0.47}
# {'loss': 1.7639, 'learning_rate': 5.871121718377089e-06, 'epoch': 0.48}
# {'loss': 1.7943, 'learning_rate': 5.847255369928402e-06, 'epoch': 0.48}
# {'loss': 1.7801, 'learning_rate': 5.823389021479714e-06, 'epoch': 0.48}
# {'loss': 1.788, 'learning_rate': 5.799522673031027e-06, 'epoch': 0.48}
# {'loss': 1.7598, 'learning_rate': 5.775656324582339e-06, 'epoch': 0.48}
# {'loss': 1.7688, 'learning_rate': 5.751789976133651e-06, 'epoch': 0.49}
# {'loss': 1.8073, 'learning_rate': 5.727923627684965e-06, 'epoch': 0.49}
# {'loss': 1.8119, 'learning_rate': 5.704057279236277e-06, 'epoch': 0.49}
# {'loss': 1.791, 'learning_rate': 5.68019093078759e-06, 'epoch': 0.49}
# {'loss': 1.7888, 'learning_rate': 5.656324582338902e-06, 'epoch': 0.49}
# {'loss': 1.7805, 'learning_rate': 5.632458233890216e-06, 'epoch': 0.5}
# {'loss': 1.911, 'learning_rate': 5.608591885441528e-06, 'epoch': 0.5}
# {'loss': 1.7985, 'learning_rate': 5.584725536992841e-06, 'epoch': 0.5}
# {'loss': 1.7973, 'learning_rate': 5.560859188544153e-06, 'epoch': 0.5}
# {'loss': 1.7943, 'learning_rate': 5.536992840095466e-06, 'epoch': 0.51}
# {'loss': 1.7965, 'learning_rate': 5.5131264916467785e-06, 'epoch': 0.51}
# {'loss': 1.789, 'learning_rate': 5.4892601431980906e-06, 'epoch': 0.51}
# {'loss': 1.7902, 'learning_rate': 5.465393794749404e-06, 'epoch': 0.51}
# {'loss': 1.8537, 'learning_rate': 5.441527446300716e-06, 'epoch': 0.51}
# {'loss': 1.7858, 'learning_rate': 5.417661097852029e-06, 'epoch': 0.52}
# {'loss': 1.7876, 'learning_rate': 5.393794749403341e-06, 'epoch': 0.52}
# {'loss': 1.68, 'learning_rate': 5.369928400954655e-06, 'epoch': 0.52}
# {'loss': 1.8044, 'learning_rate': 5.346062052505967e-06, 'epoch': 0.52}
# {'loss': 1.792, 'learning_rate': 5.322195704057279e-06, 'epoch': 0.52}
# {'loss': 1.7907, 'learning_rate': 5.298329355608593e-06, 'epoch': 0.53}
# {'loss': 1.789, 'learning_rate': 5.274463007159905e-06, 'epoch': 0.53}
# {'loss': 1.7931, 'learning_rate': 5.250596658711218e-06, 'epoch': 0.53}
# {'loss': 1.7814, 'learning_rate': 5.22673031026253e-06, 'epoch': 0.53}
# {'loss': 1.7801, 'learning_rate': 5.2028639618138435e-06, 'epoch': 0.54}
# {'loss': 1.8624, 'learning_rate': 5.1789976133651555e-06, 'epoch': 0.54}
# {'loss': 1.8031, 'learning_rate': 5.155131264916468e-06, 'epoch': 0.54}
# {'loss': 1.7963, 'learning_rate': 5.13126491646778e-06, 'epoch': 0.54}
# {'loss': 1.8124, 'learning_rate': 5.107398568019093e-06, 'epoch': 0.54}
# {'loss': 1.79, 'learning_rate': 5.083532219570406e-06, 'epoch': 0.55}
# {'loss': 1.8035, 'learning_rate': 5.059665871121718e-06, 'epoch': 0.55}
# {'loss': 1.8166, 'learning_rate': 5.035799522673032e-06, 'epoch': 0.55}
# {'loss': 1.7944, 'learning_rate': 5.011933174224344e-06, 'epoch': 0.55}
# {'loss': 1.7753, 'learning_rate': 4.988066825775657e-06, 'epoch': 0.55}
# {'loss': 1.7807, 'learning_rate': 4.964200477326969e-06, 'epoch': 0.56}
# {'loss': 1.8059, 'learning_rate': 4.940334128878282e-06, 'epoch': 0.56}
# {'loss': 1.7858, 'learning_rate': 4.916467780429595e-06, 'epoch': 0.56}
# {'loss': 1.7811, 'learning_rate': 4.8926014319809075e-06, 'epoch': 0.56}
# {'loss': 1.7973, 'learning_rate': 4.86873508353222e-06, 'epoch': 0.57}
# {'loss': 1.7835, 'learning_rate': 4.8448687350835324e-06, 'epoch': 0.57}
# {'loss': 1.7775, 'learning_rate': 4.821002386634845e-06, 'epoch': 0.57}
# {'loss': 1.7903, 'learning_rate': 4.797136038186158e-06, 'epoch': 0.57}
# {'loss': 1.7857, 'learning_rate': 4.77326968973747e-06, 'epoch': 0.57}
# {'loss': 1.7285, 'learning_rate': 4.749403341288783e-06, 'epoch': 0.58}
# {'loss': 1.7986, 'learning_rate': 4.725536992840096e-06, 'epoch': 0.58}
# {'loss': 1.7844, 'learning_rate': 4.701670644391408e-06, 'epoch': 0.58}
# {'loss': 1.7896, 'learning_rate': 4.677804295942721e-06, 'epoch': 0.58}
# {'loss': 1.7776, 'learning_rate': 4.653937947494034e-06, 'epoch': 0.58}
# {'loss': 1.7638, 'learning_rate': 4.630071599045347e-06, 'epoch': 0.59}
# {'loss': 1.7916, 'learning_rate': 4.6062052505966596e-06, 'epoch': 0.59}
# {'loss': 1.7726, 'learning_rate': 4.582338902147972e-06, 'epoch': 0.59}
# {'loss': 1.7795, 'learning_rate': 4.5584725536992845e-06, 'epoch': 0.59}
# {'loss': 1.7805, 'learning_rate': 4.5346062052505965e-06, 'epoch': 0.59}
# {'loss': 1.7877, 'learning_rate': 4.510739856801909e-06, 'epoch': 0.6}
# {'loss': 1.7999, 'learning_rate': 4.486873508353222e-06, 'epoch': 0.6}
# {'loss': 1.7769, 'learning_rate': 4.463007159904535e-06, 'epoch': 0.6}
# {'loss': 1.7858, 'learning_rate': 4.439140811455848e-06, 'epoch': 0.6}
# {'loss': 1.7802, 'learning_rate': 4.41527446300716e-06, 'epoch': 0.61}
# {'loss': 1.7682, 'learning_rate': 4.391408114558473e-06, 'epoch': 0.61}
# {'loss': 1.7983, 'learning_rate': 4.367541766109786e-06, 'epoch': 0.61}
# {'loss': 1.7895, 'learning_rate': 4.343675417661099e-06, 'epoch': 0.61}
# {'loss': 1.7951, 'learning_rate': 4.319809069212411e-06, 'epoch': 0.61}
# {'loss': 1.7969, 'learning_rate': 4.295942720763724e-06, 'epoch': 0.62}
# {'loss': 1.789, 'learning_rate': 4.272076372315036e-06, 'epoch': 0.62}
# {'loss': 1.7792, 'learning_rate': 4.2482100238663486e-06, 'epoch': 0.62}
# {'loss': 1.7826, 'learning_rate': 4.2243436754176614e-06, 'epoch': 0.62}
# {'loss': 1.7865, 'learning_rate': 4.200477326968974e-06, 'epoch': 0.62}
# {'loss': 1.7854, 'learning_rate': 4.176610978520287e-06, 'epoch': 0.63}
# {'loss': 1.7949, 'learning_rate': 4.152744630071599e-06, 'epoch': 0.63}
# {'loss': 1.7911, 'learning_rate': 4.128878281622912e-06, 'epoch': 0.63}
# {'loss': 1.7847, 'learning_rate': 4.105011933174224e-06, 'epoch': 0.63}
# {'loss': 1.7549, 'learning_rate': 4.081145584725537e-06, 'epoch': 0.64}
# {'loss': 1.7758, 'learning_rate': 4.05727923627685e-06, 'epoch': 0.64}
# {'loss': 1.7848, 'learning_rate': 4.033412887828163e-06, 'epoch': 0.64}
# {'loss': 1.783, 'learning_rate': 4.009546539379475e-06, 'epoch': 0.64}
# {'loss': 1.7843, 'learning_rate': 3.985680190930788e-06, 'epoch': 0.64}
# {'loss': 1.7875, 'learning_rate': 3.961813842482101e-06, 'epoch': 0.65}
# {'loss': 1.7826, 'learning_rate': 3.9379474940334135e-06, 'epoch': 0.65}
# {'loss': 1.7862, 'learning_rate': 3.914081145584726e-06, 'epoch': 0.65}
# {'loss': 1.8026, 'learning_rate': 3.890214797136038e-06, 'epoch': 0.65}
# {'loss': 1.7825, 'learning_rate': 3.866348448687351e-06, 'epoch': 0.65}
# {'loss': 1.7829, 'learning_rate': 3.842482100238663e-06, 'epoch': 0.66}
# {'loss': 1.7711, 'learning_rate': 3.818615751789976e-06, 'epoch': 0.66}
# {'loss': 1.7839, 'learning_rate': 3.794749403341289e-06, 'epoch': 0.66}
# {'loss': 1.7914, 'learning_rate': 3.770883054892602e-06, 'epoch': 0.66}
# {'loss': 1.797, 'learning_rate': 3.7470167064439144e-06, 'epoch': 0.67}
# {'loss': 1.778, 'learning_rate': 3.7231503579952273e-06, 'epoch': 0.67}
# {'loss': 1.7835, 'learning_rate': 3.6992840095465398e-06, 'epoch': 0.67}
# {'loss': 1.7897, 'learning_rate': 3.6754176610978526e-06, 'epoch': 0.67}
# {'loss': 1.7787, 'learning_rate': 3.6515513126491647e-06, 'epoch': 0.67}
# {'loss': 1.8029, 'learning_rate': 3.6276849642004776e-06, 'epoch': 0.68}
# {'loss': 1.8074, 'learning_rate': 3.60381861575179e-06, 'epoch': 0.68}
# {'loss': 1.8108, 'learning_rate': 3.579952267303103e-06, 'epoch': 0.68}
# {'loss': 1.7831, 'learning_rate': 3.5560859188544154e-06, 'epoch': 0.68}
# {'loss': 1.8003, 'learning_rate': 3.5322195704057282e-06, 'epoch': 0.68}
# {'loss': 1.7826, 'learning_rate': 3.508353221957041e-06, 'epoch': 0.69}
# {'loss': 1.7966, 'learning_rate': 3.4844868735083536e-06, 'epoch': 0.69}
# {'loss': 1.7932, 'learning_rate': 3.4606205250596665e-06, 'epoch': 0.69}
# {'loss': 1.8231, 'learning_rate': 3.4367541766109785e-06, 'epoch': 0.69}
# {'loss': 1.8058, 'learning_rate': 3.4128878281622914e-06, 'epoch': 0.7}
# {'loss': 1.795, 'learning_rate': 3.389021479713604e-06, 'epoch': 0.7}
# {'loss': 1.8071, 'learning_rate': 3.3651551312649167e-06, 'epoch': 0.7}
# {'loss': 1.7881, 'learning_rate': 3.341288782816229e-06, 'epoch': 0.7}
# {'loss': 1.8129, 'learning_rate': 3.317422434367542e-06, 'epoch': 0.7}
# {'loss': 1.7916, 'learning_rate': 3.293556085918855e-06, 'epoch': 0.71}
# {'loss': 1.8352, 'learning_rate': 3.2696897374701674e-06, 'epoch': 0.71}
# {'loss': 1.7786, 'learning_rate': 3.2458233890214803e-06, 'epoch': 0.71}
# {'loss': 1.7931, 'learning_rate': 3.2219570405727923e-06, 'epoch': 0.71}
# {'loss': 1.8, 'learning_rate': 3.198090692124105e-06, 'epoch': 0.71}
# {'loss': 1.7817, 'learning_rate': 3.1742243436754176e-06, 'epoch': 0.72}
# {'loss': 1.6431, 'learning_rate': 3.1503579952267305e-06, 'epoch': 0.72}
# {'loss': 1.7935, 'learning_rate': 3.126491646778043e-06, 'epoch': 0.72}
# {'loss': 1.7741, 'learning_rate': 3.102625298329356e-06, 'epoch': 0.72}
# {'loss': 1.7827, 'learning_rate': 3.0787589498806688e-06, 'epoch': 0.72}
# {'loss': 1.7851, 'learning_rate': 3.054892601431981e-06, 'epoch': 0.73}
# {'loss': 1.8006, 'learning_rate': 3.031026252983294e-06, 'epoch': 0.73}
# {'loss': 1.7949, 'learning_rate': 3.0071599045346066e-06, 'epoch': 0.73}
# {'loss': 1.7811, 'learning_rate': 2.983293556085919e-06, 'epoch': 0.73}
# {'loss': 1.7819, 'learning_rate': 2.9594272076372315e-06, 'epoch': 0.74}
# {'loss': 1.7854, 'learning_rate': 2.9355608591885443e-06, 'epoch': 0.74}
# {'loss': 1.7824, 'learning_rate': 2.911694510739857e-06, 'epoch': 0.74}
# {'loss': 1.8024, 'learning_rate': 2.8878281622911697e-06, 'epoch': 0.74}
# {'loss': 1.7781, 'learning_rate': 2.8639618138424826e-06, 'epoch': 0.74}
# {'loss': 1.7906, 'learning_rate': 2.840095465393795e-06, 'epoch': 0.75}
# {'loss': 1.8002, 'learning_rate': 2.816229116945108e-06, 'epoch': 0.75}
# {'loss': 1.788, 'learning_rate': 2.7923627684964204e-06, 'epoch': 0.75}
# {'loss': 1.8026, 'learning_rate': 2.768496420047733e-06, 'epoch': 0.75}
# {'loss': 1.7934, 'learning_rate': 2.7446300715990453e-06, 'epoch': 0.75}
# {'loss': 1.7821, 'learning_rate': 2.720763723150358e-06, 'epoch': 0.76}
# {'loss': 1.7936, 'learning_rate': 2.6968973747016706e-06, 'epoch': 0.76}
# {'loss': 1.7873, 'learning_rate': 2.6730310262529835e-06, 'epoch': 0.76}
# {'loss': 1.7146, 'learning_rate': 2.6491646778042964e-06, 'epoch': 0.76}
# {'loss': 1.7999, 'learning_rate': 2.625298329355609e-06, 'epoch': 0.77}
# {'loss': 1.7965, 'learning_rate': 2.6014319809069217e-06, 'epoch': 0.77}
# {'loss': 1.8646, 'learning_rate': 2.577565632458234e-06, 'epoch': 0.77}
# {'loss': 1.7731, 'learning_rate': 2.5536992840095466e-06, 'epoch': 0.77}
# {'loss': 1.7787, 'learning_rate': 2.529832935560859e-06, 'epoch': 0.77}
# {'loss': 1.7788, 'learning_rate': 2.505966587112172e-06, 'epoch': 0.78}
# {'loss': 1.8044, 'learning_rate': 2.4821002386634844e-06, 'epoch': 0.78}
# {'loss': 1.795, 'learning_rate': 2.4582338902147973e-06, 'epoch': 0.78}
# {'loss': 1.786, 'learning_rate': 2.43436754176611e-06, 'epoch': 0.78}
# {'loss': 1.7751, 'learning_rate': 2.4105011933174227e-06, 'epoch': 0.78}
# {'loss': 1.7848, 'learning_rate': 2.386634844868735e-06, 'epoch': 0.79}
# {'loss': 1.7885, 'learning_rate': 2.362768496420048e-06, 'epoch': 0.79}
# {'loss': 1.7853, 'learning_rate': 2.3389021479713605e-06, 'epoch': 0.79}
# {'loss': 1.7771, 'learning_rate': 2.3150357995226733e-06, 'epoch': 0.79}
# {'loss': 1.7774, 'learning_rate': 2.291169451073986e-06, 'epoch': 0.8}
# {'loss': 1.7741, 'learning_rate': 2.2673031026252983e-06, 'epoch': 0.8}
# {'loss': 1.7855, 'learning_rate': 2.243436754176611e-06, 'epoch': 0.8}
# {'loss': 1.794, 'learning_rate': 2.219570405727924e-06, 'epoch': 0.8}
# {'loss': 1.7268, 'learning_rate': 2.1957040572792365e-06, 'epoch': 0.8}
# {'loss': 1.7912, 'learning_rate': 2.1718377088305494e-06, 'epoch': 0.81}
# {'loss': 1.7834, 'learning_rate': 2.147971360381862e-06, 'epoch': 0.81}
# {'loss': 1.7847, 'learning_rate': 2.1241050119331743e-06, 'epoch': 0.81}
# {'loss': 1.8018, 'learning_rate': 2.100238663484487e-06, 'epoch': 0.81}
# {'loss': 1.7818, 'learning_rate': 2.0763723150357996e-06, 'epoch': 0.81}
# {'loss': 1.7998, 'learning_rate': 2.052505966587112e-06, 'epoch': 0.82}
# {'loss': 1.786, 'learning_rate': 2.028639618138425e-06, 'epoch': 0.82}
# {'loss': 1.786, 'learning_rate': 2.0047732696897374e-06, 'epoch': 0.82}
# {'loss': 1.7815, 'learning_rate': 1.9809069212410503e-06, 'epoch': 0.82}
# {'loss': 1.7655, 'learning_rate': 1.957040572792363e-06, 'epoch': 0.83}
# {'loss': 1.778, 'learning_rate': 1.9331742243436756e-06, 'epoch': 0.83}
# {'loss': 1.8025, 'learning_rate': 1.909307875894988e-06, 'epoch': 0.83}
# {'loss': 1.7874, 'learning_rate': 1.885441527446301e-06, 'epoch': 0.83}
# {'loss': 1.7942, 'learning_rate': 1.8615751789976136e-06, 'epoch': 0.83}
# {'loss': 1.7874, 'learning_rate': 1.8377088305489263e-06, 'epoch': 0.84}
# {'loss': 1.6933, 'learning_rate': 1.8138424821002388e-06, 'epoch': 0.84}
# {'loss': 1.787, 'learning_rate': 1.7899761336515514e-06, 'epoch': 0.84}
# {'loss': 1.7609, 'learning_rate': 1.7661097852028641e-06, 'epoch': 0.84}
# {'loss': 1.788, 'learning_rate': 1.7422434367541768e-06, 'epoch': 0.84}
# {'loss': 1.7653, 'learning_rate': 1.7183770883054892e-06, 'epoch': 0.85}
# {'loss': 1.7944, 'learning_rate': 1.694510739856802e-06, 'epoch': 0.85}
# {'loss': 1.7869, 'learning_rate': 1.6706443914081146e-06, 'epoch': 0.85}
# {'loss': 1.7885, 'learning_rate': 1.6467780429594275e-06, 'epoch': 0.85}
# {'loss': 1.7871, 'learning_rate': 1.6229116945107401e-06, 'epoch': 0.86}
# {'loss': 1.7835, 'learning_rate': 1.5990453460620526e-06, 'epoch': 0.86}
# {'loss': 1.8894, 'learning_rate': 1.5751789976133653e-06, 'epoch': 0.86}
# {'loss': 1.7909, 'learning_rate': 1.551312649164678e-06, 'epoch': 0.86}
# {'loss': 1.7953, 'learning_rate': 1.5274463007159906e-06, 'epoch': 0.86}
# {'loss': 1.7854, 'learning_rate': 1.5035799522673033e-06, 'epoch': 0.87}
# {'loss': 1.7751, 'learning_rate': 1.4797136038186157e-06, 'epoch': 0.87}
# {'loss': 1.7844, 'learning_rate': 1.4558472553699284e-06, 'epoch': 0.87}
# {'loss': 1.7781, 'learning_rate': 1.4319809069212413e-06, 'epoch': 0.87}
# {'loss': 1.7791, 'learning_rate': 1.408114558472554e-06, 'epoch': 0.87}
# {'loss': 1.7789, 'learning_rate': 1.3842482100238664e-06, 'epoch': 0.88}
# {'loss': 1.7767, 'learning_rate': 1.360381861575179e-06, 'epoch': 0.88}
# {'loss': 1.7844, 'learning_rate': 1.3365155131264918e-06, 'epoch': 0.88}
# {'loss': 1.7818, 'learning_rate': 1.3126491646778044e-06, 'epoch': 0.88}
# {'loss': 1.7732, 'learning_rate': 1.288782816229117e-06, 'epoch': 0.88}
# {'loss': 1.7867, 'learning_rate': 1.2649164677804296e-06, 'epoch': 0.89}
# {'loss': 1.7862, 'learning_rate': 1.2410501193317422e-06, 'epoch': 0.89}
# {'loss': 1.8094, 'learning_rate': 1.217183770883055e-06, 'epoch': 0.89}
# {'loss': 1.7915, 'learning_rate': 1.1933174224343676e-06, 'epoch': 0.89}
# {'loss': 1.7817, 'learning_rate': 1.1694510739856802e-06, 'epoch': 0.9}
# {'loss': 1.7794, 'learning_rate': 1.145584725536993e-06, 'epoch': 0.9}
# {'loss': 1.7909, 'learning_rate': 1.1217183770883056e-06, 'epoch': 0.9}
# {'loss': 1.786, 'learning_rate': 1.0978520286396182e-06, 'epoch': 0.9}
# {'loss': 1.7912, 'learning_rate': 1.073985680190931e-06, 'epoch': 0.9}
# {'loss': 1.7765, 'learning_rate': 1.0501193317422436e-06, 'epoch': 0.91}
# {'loss': 1.7761, 'learning_rate': 1.026252983293556e-06, 'epoch': 0.91}
# {'loss': 1.7835, 'learning_rate': 1.0023866348448687e-06, 'epoch': 0.91}
# {'loss': 1.7788, 'learning_rate': 9.785202863961816e-07, 'epoch': 0.91}
# {'loss': 1.8703, 'learning_rate': 9.54653937947494e-07, 'epoch': 0.91}
# {'loss': 1.7924, 'learning_rate': 9.307875894988068e-07, 'epoch': 0.92}
# {'loss': 1.7918, 'learning_rate': 9.069212410501194e-07, 'epoch': 0.92}
# {'loss': 1.777, 'learning_rate': 8.830548926014321e-07, 'epoch': 0.92}
# {'loss': 1.7727, 'learning_rate': 8.591885441527446e-07, 'epoch': 0.92}
# {'loss': 1.7917, 'learning_rate': 8.353221957040573e-07, 'epoch': 0.93}
# {'loss': 1.7915, 'learning_rate': 8.114558472553701e-07, 'epoch': 0.93}
# {'loss': 1.7766, 'learning_rate': 7.875894988066826e-07, 'epoch': 0.93}
# {'loss': 1.7804, 'learning_rate': 7.637231503579953e-07, 'epoch': 0.93}
# {'loss': 1.7834, 'learning_rate': 7.398568019093079e-07, 'epoch': 0.93}
# {'loss': 1.7781, 'learning_rate': 7.159904534606206e-07, 'epoch': 0.94}
# {'loss': 1.7868, 'learning_rate': 6.921241050119332e-07, 'epoch': 0.94}
# {'loss': 1.7788, 'learning_rate': 6.682577565632459e-07, 'epoch': 0.94}
# {'loss': 1.7943, 'learning_rate': 6.443914081145585e-07, 'epoch': 0.94}
# {'loss': 1.7742, 'learning_rate': 6.205250596658711e-07, 'epoch': 0.94}
# {'loss': 1.7961, 'learning_rate': 5.966587112171838e-07, 'epoch': 0.95}
# {'loss': 1.7832, 'learning_rate': 5.727923627684965e-07, 'epoch': 0.95}
# {'loss': 1.767, 'learning_rate': 5.489260143198091e-07, 'epoch': 0.95}
# {'loss': 1.7795, 'learning_rate': 5.250596658711218e-07, 'epoch': 0.95}
# {'loss': 1.7799, 'learning_rate': 5.011933174224344e-07, 'epoch': 0.96}
# {'loss': 1.78, 'learning_rate': 4.77326968973747e-07, 'epoch': 0.96}
# {'loss': 1.7921, 'learning_rate': 4.534606205250597e-07, 'epoch': 0.96}
# {'loss': 1.7886, 'learning_rate': 4.295942720763723e-07, 'epoch': 0.96}
# {'loss': 1.797, 'learning_rate': 4.0572792362768503e-07, 'epoch': 0.96}
# {'loss': 1.7877, 'learning_rate': 3.8186157517899765e-07, 'epoch': 0.97}
# {'loss': 1.7842, 'learning_rate': 3.579952267303103e-07, 'epoch': 0.97}
# {'loss': 1.7782, 'learning_rate': 3.3412887828162294e-07, 'epoch': 0.97}
# {'loss': 1.7926, 'learning_rate': 3.1026252983293556e-07, 'epoch': 0.97}
# {'loss': 1.8136, 'learning_rate': 2.863961813842482e-07, 'epoch': 0.97}
# {'loss': 1.7854, 'learning_rate': 2.625298329355609e-07, 'epoch': 0.98}
# {'loss': 1.7785, 'learning_rate': 2.386634844868735e-07, 'epoch': 0.98}
# {'loss': 1.7863, 'learning_rate': 2.1479713603818616e-07, 'epoch': 0.98}
# {'loss': 1.7256, 'learning_rate': 1.9093078758949883e-07, 'epoch': 0.98}
# {'loss': 1.7918, 'learning_rate': 1.6706443914081147e-07, 'epoch': 0.99}
# {'loss': 1.7706, 'learning_rate': 1.431980906921241e-07, 'epoch': 0.99}
# {'loss': 1.7983, 'learning_rate': 1.1933174224343676e-07, 'epoch': 0.99}
# {'loss': 1.7789, 'learning_rate': 9.546539379474941e-08, 'epoch': 0.99}
# {'loss': 1.79, 'learning_rate': 7.159904534606206e-08, 'epoch': 0.99}
# {'loss': 1.7955, 'learning_rate': 4.7732696897374706e-08, 'epoch': 1.0}
# {'loss': 1.7893, 'learning_rate': 2.3866348448687353e-08, 'epoch': 1.0}
# {'loss': 1.7737, 'learning_rate': 0.0, 'epoch': 1.0}
#   0%|          | 0/118 [00:00<?, ?it/s]
# Checkpoint destination directory multiple_accent_classification\checkpoint-469 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# {'eval_loss': 1.7802815437316895, 'eval_roc_auc': 0.725399157449508, 'eval_accuracy': 0.32127659574468087, 'eval_runtime': 342.2602, 'eval_samples_per_second': 1.373, 'eval_steps_per_second': 0.345, 'epoch': 1.0}
# {'train_runtime': 5909.1041, 'train_samples_per_second': 0.317, 'train_steps_per_second': 0.079, 'train_loss': 1.7911806914852118, 'epoch': 1.0}
# TrainOutput(global_step=469, training_loss=1.7911806914852118, metrics={'train_runtime': 5909.1041, 'train_samples_per_second': 0.317, 'train_steps_per_second': 0.079, 'train_loss': 1.7911806914852118, 'epoch': 1.0})

# %%
trainer.evaluate()
# Out:
#   0%|          | 0/118 [00:00<?, ?it/s]
# {'eval_loss': 1.7802815437316895,
#  'eval_roc_auc': 0.725399157449508,
#  'eval_accuracy': 0.32127659574468087,
#  'eval_runtime': 350.5905,
#  'eval_samples_per_second': 1.341,
#  'eval_steps_per_second': 0.337,
#  'epoch': 1.0}

# %%
trainer.save_model()

# %%
from transformers import pipeline

pipe=pipeline('audio-classification',model=model_name)

# %%
audio,rate=torchaudio.load('recordings/recordings/mandarin45.mp3')
transform=torchaudio.transforms.Resample(rate,16000)
audio=transform(audio).numpy().reshape(-1)
# make a classification pipeline
pipe(audio)
# Out:
# [{'score': 0.1710423231124878, 'label': 'other'},
#  {'score': 0.1693054437637329, 'label': 'china'},
#  {'score': 0.1677512228488922, 'label': 'usa'},
#  {'score': 0.16580599546432495, 'label': 'india'},
#  {'score': 0.16341271996498108, 'label': 'canada'}]

# %%
audio,rate=torchaudio.load('recordings/recordings/english43.mp3')
transform=torchaudio.transforms.Resample(rate,16000)
audio=transform(audio).numpy().reshape(-1)
pipe(audio)
# Out:
# [{'score': 0.1762453019618988, 'label': 'canada'},
#  {'score': 0.17137624323368073, 'label': 'usa'},
#  {'score': 0.16640238463878632, 'label': 'other'},
#  {'score': 0.16438382863998413, 'label': 'uk'},
#  {'score': 0.16370856761932373, 'label': 'india'}]
